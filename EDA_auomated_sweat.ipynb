# %%
import pandas as pd
import sweetviz as sv
import os

# %%
path = "C:/Users/samuel.k/Desktop/temp/oct_30/Data"
table_list = os.listdir(path)

# %%
table_list
# Out:
# ['buildingeasementmanager.csv',
#  'buildingfiles.csv',
#  'buildinglateralmanager.csv',
#  'buildinglist.csv',
#  'buildinglist_user.csv',
#  'buildingpropertymanager.csv',
#  'buildingrisermanager.csv',
#  'buildingservice.csv',
#  'c2f_census_concat_ref.csv',
#  'c2f_dns_ref.csv',
#  'c2f_es_search_config.csv',
#  'c2f_instance_nonreseller_flag.csv',
#  'c2f_master_enrichment_data.csv',
#  'c2f_me_no_results.csv',
#  'c2f_mso_all_ref.csv',
#  'c2f_provider_name_ref.csv',
#  'c2f_us_city_ref.csv',
#  'cableownership.csv',
#  'centurylink_locations.csv',
#  'city.csv',
#  'cofinder_ref.csv',
#  'common_audit_log.csv',
#  'company.csv',
#  'companyproductcomponent.csv',
#  'companyservice.csv',
#  'company_building.csv',
#  'company_building_new.csv',
#  'company_building_nni_location.csv',
#  'company_client.csv',
#  'company_geography_rule.csv',
#  'company_location_type_subscription.csv',
#  'company_nni_service.csv',
#  'company_ocn_track.csv',
# ...

# %%
table_names=[]
for a in table_list:
    table_names.append(a[:-4])

# %%
table_names
# Out:
# ['buildingeasementmanager',
#  'buildingfiles',
#  'buildinglateralmanager',
#  'buildinglist',
#  'buildinglist_user',
#  'buildingpropertymanager',
#  'buildingrisermanager',
#  'buildingservice',
#  'c2f_census_concat_ref',
#  'c2f_dns_ref',
#  'c2f_es_search_config',
#  'c2f_instance_nonreseller_flag',
#  'c2f_master_enrichment_data',
#  'c2f_me_no_results',
#  'c2f_mso_all_ref',
#  'c2f_provider_name_ref',
#  'c2f_us_city_ref',
#  'cableownership',
#  'centurylink_locations',
#  'city',
#  'cofinder_ref',
#  'common_audit_log',
#  'company',
#  'companyproductcomponent',
#  'companyservice',
#  'company_building',
#  'company_building_new',
#  'company_building_nni_location',
#  'company_client',
#  'company_geography_rule',
#  'company_location_type_subscription',
#  'company_nni_service',
#  'company_ocn_track',
#  'company_pricing_geography',
#  'company_region',
#  'company_spatial_boundary',
#  'company_state_subscription',
#  'company_status',
#  'company_supplier',
# ...

# %%
for a in  table_names[35:]:
    #EDA using Autoviz
    b=a+".csv"
    sweet_report = sv.analyze(pd.read_csv(b))
    #Saving results to HTML file
    report_name = a+'.html'
    sweet_report.show_html(report_name)
    print(a+'is reported')
# Out:
# ...
# Report company_spatial_boundary.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
# company_spatial_boundaryis reported
# ...
# Report company_state_subscription.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
# company_state_subscriptionis reported
# ...
# Report company_status.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
# company_statusis reported
# ...
# Report company_supplier.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
# company_supplieris reported
# ...
# Report company_uni_service.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
# company_uni_serviceis reported
# ...

# %%
a
