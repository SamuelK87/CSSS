# %% [markdown]
# ### Importing libraries

# %%
from sqlalchemy import create_engine
import pandas as pd
import sweetviz as sv
import os

# %% [markdown]
# ### sql DB connection

# %%
engine = create_engine("mysql://ml_read_user:ML@user@123@127.0.0.1:3307/connected2fiber",echo = True)

# %% [markdown]
# ### Exploring buildinglist

# %%
con = engine.connect()
rs = con.execute("SELECT * FROM `buildinglist`")
df = pd.DataFrame(rs.fetchall())
df.columns = rs.keys()
con.close()
print("###################")
print("SHAPE {}".format(df.shape))
print("###################")
print("COLUMNS {}".format(df.columns))
print("###################")
print(df.head())
# Out:
# 2021-07-26 09:40:39,765 INFO sqlalchemy.engine.base.Engine SHOW VARIABLES LIKE 'sql_mode'
# 2021-07-26 09:40:39,774 INFO sqlalchemy.engine.base.Engine ()
# 2021-07-26 09:40:40,016 INFO sqlalchemy.engine.base.Engine SHOW VARIABLES LIKE 'lower_case_table_names'
# 2021-07-26 09:40:40,018 INFO sqlalchemy.engine.base.Engine ()
# 2021-07-26 09:40:40,501 INFO sqlalchemy.engine.base.Engine SELECT DATABASE()
# 2021-07-26 09:40:40,503 INFO sqlalchemy.engine.base.Engine ()
# 2021-07-26 09:40:40,981 INFO sqlalchemy.engine.base.Engine show collation where `Charset` = 'utf8mb4' and `Collation` = 'utf8mb4_bin'
# 2021-07-26 09:40:40,982 INFO sqlalchemy.engine.base.Engine ()
# 2021-07-26 09:40:41,223 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS CHAR(60)) AS anon_1
# 2021-07-26 09:40:41,225 INFO sqlalchemy.engine.base.Engine ()
# 2021-07-26 09:40:41,465 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS CHAR(60)) AS anon_1
# ...

# %% [markdown]
# ### network_provider_user_entry

# %%
con = engine.connect()
rs = con.execute("SELECT * FROM `network_provider_user_entry`")
df = pd.DataFrame(rs.fetchall())
df.columns = rs.keys()
con.close()
print("###################")
print("SHAPE {}".format(df.shape))
print("###################")
print("COLUMNS {}".format(df.columns))
print("###################")
print(df.head())
# Out:
# 2021-07-26 09:43:02,947 INFO sqlalchemy.engine.base.Engine SELECT * FROM `network_provider_user_entry`
# 2021-07-26 09:43:02,948 INFO sqlalchemy.engine.base.Engine ()
# ###################
# SHAPE (52, 20)
# ###################
# COLUMNS Index(['id', 'carrier', 'category_id', 'access_type', 'status',
#        'entrance_capability_id', 'site_distance', 'closest_site', 'company_id',
#        'es_identifier', 'cf_address_key', 'is_deleted', 'created_account_id',
#        'created_date', 'modified_account_id', 'modified_date',
#        'is_newly_added', 'source_address_key', 'network_status',
#        'cf_unique_key'],
#       dtype='object')
# ###################
#    id                  carrier  category_id access_type    status  \
# 0   1                   market            0    Coax/HFC     onnet
# 1   2  Testing Demo   Anumanth            6       Fiber  Near Net
# 2   3  Testing Demo   Anumanth            0       Fiber  Near Net
# ...

# %% [markdown]
# ### buildingservice

# %%
con = engine.connect()
rs = con.execute("SELECT * FROM `buildingservice`")
df = pd.DataFrame(rs.fetchall())
df.columns = rs.keys()
con.close()
print("###################")
print("SHAPE {}".format(df.shape))
print("###################")
print("COLUMNS {}".format(df.columns))
print("###################")
print(df.head())
# Out:
# 2021-07-26 10:40:19,470 INFO sqlalchemy.engine.base.Engine SELECT * FROM `buildingservice`
# 2021-07-26 10:40:19,472 INFO sqlalchemy.engine.base.Engine ()
# ###################
# SHAPE (49425, 37)
# ###################
# COLUMNS Index(['buildingserviceid', 'buildingid', 'servicespeedid', 'mrc_12m',
#        'nrc_12m', 'speedavailability', 'mrc_24m', 'nrc_24m', 'mrc_36m',
#        'nrc_36m', 'mrc_48m', 'nrc_48m', 'mrc_60m', 'nrc_60m', 'mrc_84m',
#        'nrc_84m', 'mrc_120m', 'nrc_120m', 'mrc_240m', 'nrc_240m', 'mm_mrc',
#        'mm_nrc', 'company_id', 'createdaccountid', 'modifiedaccountid',
#        'createddate', 'modifieddate', 'isdeleted', 'pricing_channel_id',
#        'network_connection_status', 'building_connection_status',
#        'access_medium_id', 'geographic_config_id', 'entity_id',
#        'building_competitive_rating', 'building_category_id',
#        'distance_band_id'],
#       dtype='object')
# ###################
# ...

# %%
    #EDA using Autoviz
    #b=a+".csv"
    
    a= "buildingservice"
    sweet_report = sv.analyze(df)
    #Saving results to HTML file
    report_name = a+'.html'
    sweet_report.show_html(report_name)
# Out:
# ...
# Report buildingservice.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %% [markdown]
# ## building_uni_service

# %%
con = engine.connect()
rs = con.execute("SELECT * FROM `building_uni_service`")
df = pd.DataFrame(rs.fetchall())
df.columns = rs.keys()
con.close()
print("###################")
print("SHAPE {}".format(df.shape))
print("###################")
print("COLUMNS {}".format(df.columns))
print("###################")
print(df.head())
# Out:
# 2021-07-26 09:46:15,269 INFO sqlalchemy.engine.base.Engine SELECT * FROM `building_uni_service`
# 2021-07-26 09:46:15,270 INFO sqlalchemy.engine.base.Engine ()
# ###################
# SHAPE (1311, 27)
# ###################
# COLUMNS Index(['building_uni_service_id', 'building_id', 'uni_service_speed_id',
#        'mrc_12m', 'nrc_12m', 'speed_availability', 'mrc_24m', 'nrc_24m',
#        'mrc_36m', 'nrc_36m', 'mrc_48m', 'nrc_48m', 'mrc_60m', 'nrc_60m',
#        'mrc_84m', 'nrc_84m', 'mrc_120m', 'nrc_120m', 'mrc_240m', 'nrc_240m',
#        'mm_mrc', 'mm_nrc', 'created_account_id', 'modified_account_id',
#        'created_date', 'modified_date', 'is_deleted'],
#       dtype='object')
# ###################
#    building_uni_service_id  building_id  uni_service_speed_id mrc_12m nrc_12m  \
# 0                     5330       221884                   233      23      23
# 1                     5331       221884                   234     123     123
# ...

# %% [markdown]
# ### companyservice

# %%
con = engine.connect()
rs = con.execute("SELECT * FROM `companyservice`")
df = pd.DataFrame(rs.fetchall())
df.columns = rs.keys()
con.close()
print("###################")
print("SHAPE {}".format(df.shape))
print("###################")
print("COLUMNS {}".format(df.columns))
print("###################")
print(df.head())
# Out:
# 2021-07-26 10:43:42,982 INFO sqlalchemy.engine.base.Engine SELECT * FROM `companyservice`
# 2021-07-26 10:43:42,985 INFO sqlalchemy.engine.base.Engine ()
# ###################
# SHAPE (33404, 36)
# ###################
# COLUMNS Index(['companyserviceid', 'companyid', 'servicespeedid', 'mrc_12m', 'nrc_12m',
#        'speedavailability', 'mrc_24m', 'nrc_24m', 'mrc_36m', 'nrc_36m',
#        'mrc_48m', 'nrc_48m', 'mrc_60m', 'nrc_60m', 'mrc_84m', 'nrc_84m',
#        'mrc_120m', 'nrc_120m', 'mrc_240m', 'nrc_240m', 'mm_mrc', 'mm_nrc',
#        'md_entity_id', 'pricing_channel_id', 'network_connection_status',
#        'building_connection_status', 'access_medium_id',
#        'geographic_config_id', 'created_account_id', 'modified_account_id',
#        'created_date', 'modified_date', 'entity_id', 'competitive_rating',
#        'category', 'distance_band_id'],
#       dtype='object')
# ###################
#    companyserviceid  companyid  servicespeedid mrc_12m nrc_12m  \
# ...

# %%
    #EDA using Autoviz
    #b=a+".csv"
    
    a= "companyservice"
    sweet_report = sv.analyze(df)
    #Saving results to HTML file
    report_name = a+'.html'
    sweet_report.show_html(report_name)
# Out:
# ...
# Report companyservice.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %% [markdown]
# ### reportbuilding

# %%
con = engine.connect()
rs = con.execute("SELECT * FROM `reportbuilding`")
df = pd.DataFrame(rs.fetchall())
df.columns = rs.keys()
con.close()
print("###################")
print("SHAPE {}".format(df.shape))
print("###################")
print("COLUMNS {}".format(df.columns))
print("###################")
print(df.head())
# Out:
# 2021-07-26 10:11:03,713 INFO sqlalchemy.engine.base.Engine SELECT * FROM `reportbuilding`
# 2021-07-26 10:11:03,714 INFO sqlalchemy.engine.base.Engine ()
# ###################
# SHAPE (39, 13)
# ###################
# COLUMNS Index(['id', 'reporttypeid', 'message', 'createddate', 'modifieddate',
#        'supportemail', 'updatestatus', 'useraccountid', 'modifiedaccountid',
#        'entity_id', 'module_id', 'file_id', 'subject'],
#       dtype='object')
# ###################
#    id  reporttypeid                                            message  \
# 0   1             3     This site is incorrectly mapped . Please edit.
# 1   2             4                                               Test
# 2   3             4                               Thisid  test message
# 3   4             4  There is nothing wrong with this building, jus...
# 4   5             1                                               Test
#
#           createddate        modifieddate               supportemail  \
# ...

# %% [markdown]
# ### company_building_new

# %%
con = engine.connect()
rs = con.execute("SELECT * FROM `company_building_new`")
df = pd.DataFrame(rs.fetchall())
df.columns = rs.keys()
con.close()
print("###################")
print("SHAPE {}".format(df.shape))
print("###################")
print("COLUMNS {}".format(df.columns))
print("###################")
print(df.head())
# Out:
# 2021-07-26 10:11:56,097 INFO sqlalchemy.engine.base.Engine SELECT * FROM `company_building_new`
# 2021-07-26 10:11:56,098 INFO sqlalchemy.engine.base.Engine ()
# ###################
# SHAPE (5021, 100)
# ###################
# COLUMNS Index(['id', 'buildingname', 'buildingno', 'description', 'createddate',
#        'modifieddate', 'totalspaceavailable', 'sfrentalrate', 'buildingsize',
#        'additionalsubtype', 'minvisible', 'propertyvalue', 'floors',
#        'buildingclass', 'subtype', 'lotsize', 'yearbuilt', 'zoningdescription',
#        'listingid', 'lastupdateddate', 'rssfeedurl', 'twitterfeed',
#        'structurecategoryname', 'network_build_status', 'c2fbuildingnumber',
#        'demarccode', 'cllicode', 'npa', 'nxx', 'lata', 'isdarkfiber',
#        'isether', 'ismpls', 'isbroadband', 'iswifi', 'iswavelengths',
#        'issonet', 'isip', 'isdas', 'israisercablemanagement', 'israiseruser',
#        'locationid', 'structurecategory', 'cbsaname', 'onnettype',
# ...

# %% [markdown]
# ### building_supplier_service

# %%
con = engine.connect()
rs = con.execute("SELECT * FROM `building_supplier_service`")
df = pd.DataFrame(rs.fetchall())
df.columns = rs.keys()
con.close()
print("###################")
print("SHAPE {}".format(df.shape))
print("###################")
print("COLUMNS {}".format(df.columns))
print("###################")
print(df.head())
# Out:
# 2021-07-26 10:13:40,030 INFO sqlalchemy.engine.base.Engine SELECT * FROM `building_supplier_service`
# 2021-07-26 10:13:40,031 INFO sqlalchemy.engine.base.Engine ()
# ###################
# SHAPE (1842, 36)
# ###################
# COLUMNS Index(['building_supplier_service_id', 'building_id', 'service_speed_id',
#        'mrc_12m', 'nrc_12m', 'speedavailability', 'mrc_24m', 'nrc_24m',
#        'mrc_36m', 'nrc_36m', 'mrc_48m', 'nrc_48m', 'mrc_60m', 'nrc_60m',
#        'mrc_84m', 'nrc_84m', 'mrc_120m', 'nrc_120m', 'mrc_240m', 'nrc_240m',
#        'mm_mrc', 'mm_nrc', 'pricing_channel_id', 'network_connection_status',
#        'building_connection_status', 'access_medium_id',
#        'geographic_config_id', 'created_account_id', 'modified_account_id',
#        'created_date', 'modified_date', 'entity_id', 'competitive_rating',
#        'category', 'distance_band_id', 'isdeleted'],
#       dtype='object')
# ###################
# ...
