# %% [markdown]
# ### importing

# %%
from sqlalchemy import create_engine
import pandas as pd
import sweetviz as sv

# %% [markdown]
# ### sql engine

# %%
engine = create_engine("mysql://ml_read_user:ML@user@123@127.0.0.1:3307/connected2fiber",echo = True)

# %% [markdown]
# ### exploring company building new

# %%
con = engine.connect()
rs = con.execute("SELECT * FROM `company_building_new`")
df = pd.DataFrame(rs.fetchall())
df.columns = rs.keys()
con.close()
print("###################")
print("SHAPE {}".format(df.shape))
print("###################")
print("COLUMNS {}".format(df.columns))
print("###################")
print(df.head())
# Out:
# 2021-08-09 09:38:24,819 INFO sqlalchemy.engine.base.Engine SHOW VARIABLES LIKE 'sql_mode'
# 2021-08-09 09:38:24,841 INFO sqlalchemy.engine.base.Engine ()
# 2021-08-09 09:38:25,102 INFO sqlalchemy.engine.base.Engine SHOW VARIABLES LIKE 'lower_case_table_names'
# 2021-08-09 09:38:25,102 INFO sqlalchemy.engine.base.Engine ()
# 2021-08-09 09:38:25,612 INFO sqlalchemy.engine.base.Engine SELECT DATABASE()
# 2021-08-09 09:38:25,615 INFO sqlalchemy.engine.base.Engine ()
# 2021-08-09 09:38:26,106 INFO sqlalchemy.engine.base.Engine show collation where `Charset` = 'utf8mb4' and `Collation` = 'utf8mb4_bin'
# 2021-08-09 09:38:26,126 INFO sqlalchemy.engine.base.Engine ()
# 2021-08-09 09:38:26,369 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS CHAR(60)) AS anon_1
# 2021-08-09 09:38:26,385 INFO sqlalchemy.engine.base.Engine ()
# 2021-08-09 09:38:26,628 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS CHAR(60)) AS anon_1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5021 entries, 0 to 5020
# Data columns (total 100 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           5021 non-null   int64
#  1   buildingname                 5021 non-null   object
#  2   buildingno                   5021 non-null   object
#  3   description                  0 non-null      object
#  4   createddate                  5021 non-null   datetime64[ns]
#  5   modifieddate                 5021 non-null   datetime64[ns]
#  6   totalspaceavailable          0 non-null      object
#  7   sfrentalrate                 0 non-null      object
#  8   buildingsize                 0 non-null      object
#  9   additionalsubtype            0 non-null      object
#  10  minvisible                   0 non-null      object
#  11  propertyvalue                0 non-null      object
# ...

# %%
    
    a = "company_building_new"
    sweet_report = sv.analyze(df)
    #Saving results to HTML file
    report_name = a+'.html'
    sweet_report.show_html(report_name)
# Out:
# ...
# Report company_building_new.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %% [markdown]
# ## Building service

# %%
con = engine.connect()
rs = con.execute("SELECT * FROM `buildingservice`")
df = pd.DataFrame(rs.fetchall())
df.columns = rs.keys()
con.close()
print("###################")
print("SHAPE {}".format(df.shape))
print("###################")
print("COLUMNS {}".format(df.columns))
print("###################")
# Out:
# 2021-08-09 20:05:56,789 INFO sqlalchemy.engine.base.Engine SELECT * FROM `buildingservice`
# 2021-08-09 20:05:56,790 INFO sqlalchemy.engine.base.Engine ()
# ###################
# SHAPE (49429, 37)
# ###################
# COLUMNS Index(['buildingserviceid', 'buildingid', 'servicespeedid', 'mrc_12m',
#        'nrc_12m', 'speedavailability', 'mrc_24m', 'nrc_24m', 'mrc_36m',
#        'nrc_36m', 'mrc_48m', 'nrc_48m', 'mrc_60m', 'nrc_60m', 'mrc_84m',
#        'nrc_84m', 'mrc_120m', 'nrc_120m', 'mrc_240m', 'nrc_240m', 'mm_mrc',
#        'mm_nrc', 'company_id', 'createdaccountid', 'modifiedaccountid',
#        'createddate', 'modifieddate', 'isdeleted', 'pricing_channel_id',
#        'network_connection_status', 'building_connection_status',
#        'access_medium_id', 'geographic_config_id', 'entity_id',
#        'building_competitive_rating', 'building_category_id',
#        'distance_band_id'],
#       dtype='object')
# ###################

# %%
df.loc[:,'createddate' ].head()
# Out:
# 0   NaT
# 1   NaT
# 2   NaT
# 3   NaT
# 4   NaT
# Name: createddate, dtype: datetime64[ns]

# %%
df.loc[49424,'createddate' ]
# Out:
# Timestamp('2021-05-12 11:20:58')

# %%
df.loc[49424,'createddate' ].day_name()
# Out:
# 'Wednesday'

# %% [markdown]
# ### drop the rows if created date column is null

# %%
df.dropna(subset=['createddate'], inplace=True)

# %%
df.head()
# Out:
#        buildingserviceid  buildingid  servicespeedid mrc_12m nrc_12m  \
# 18449              38180      665234              47    None    None
# 18450              38181     1630989               1      45     455
# 18451              38182     1630989               3     241     524
# 18452              38183     1630989               2      78      41
# 18453              38184     1630991               1      14      54
#
#        speedavailability mrc_24m nrc_24m mrc_36m nrc_36m  ... isdeleted  \
# 18449                  1    None    None    None    None  ...         1
# 18450                  1    4455     444     444     411  ...         0
# 18451                  1      14     145     145     145  ...         0
# 18452                  1      52      45      45      45  ...         0
# 18453                  1      45      45      45     455  ...         0
#
#       pricing_channel_id network_connection_status building_connection_status  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30974 entries, 18449 to 49428
# Data columns (total 37 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   buildingserviceid            30974 non-null  int64
#  1   buildingid                   30974 non-null  int64
#  2   servicespeedid               30974 non-null  int64
#  3   mrc_12m                      29496 non-null  object
#  4   nrc_12m                      29073 non-null  object
#  5   speedavailability            30974 non-null  int64
#  6   mrc_24m                      28991 non-null  object
#  7   nrc_24m                      28749 non-null  object
#  8   mrc_36m                      28664 non-null  object
#  9   nrc_36m                      28131 non-null  object
#  10  mrc_48m                      23849 non-null  object
#  11  nrc_48m                      23839 non-null  object
#  12  mrc_60m                      28022 non-null  object
# ...

# %%
print(df.isnull().sum())
# Out:
# buildingserviceid                  0
# buildingid                         0
# servicespeedid                     0
# mrc_12m                         1478
# nrc_12m                         1901
# speedavailability                  0
# mrc_24m                         1983
# nrc_24m                         2225
# mrc_36m                         2310
# nrc_36m                         2843
# mrc_48m                         7125
# nrc_48m                         7135
# mrc_60m                         2952
# nrc_60m                         3010
# mrc_84m                        30609
# nrc_84m                        30609
# mrc_120m                       30608
# nrc_120m                       30610
# mrc_240m                       30605
# nrc_240m                       30606
# mm_mrc                         10708
# mm_nrc                         10774
# company_id                     25749
# createdaccountid                1192
# modifiedaccountid               1722
# ...

# %% [markdown]
# ## Look ups

# %%
['buildingconnectivity', ]
for table in ['network_connection_status','building_connection_status','building_competitive_rating','building_category_id']
    con = engine.connect()
    rs = con.execute("SELECT * FROM `buildingservice`")
    df = pd.DataFrame(rs.fetchall())
    df.columns = rs.keys()
    con.close()

# %% [markdown]
# ### network_connection_status

# %%
df_network_connection_status = df[['createddate', 'network_connection_status']]

# %%
df_network_connection_status.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30974 entries, 18449 to 49428
# Data columns (total 2 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   createddate                30974 non-null  datetime64[ns]
#  1   network_connection_status  21252 non-null  float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 2.0 MB

# %%
df_network_connection_status.isnull().sum()
# Out:
# createddate                     0
# network_connection_status    9722
# dtype: int64

# %%
df_network_connection_status.dropna(subset=['network_connection_status'], inplace=True)
# Out:
# <ipython-input-63-70c2ea3c65b8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_network_connection_status.dropna(subset=['network_connection_status'], inplace=True)

# %%
df_network_connection_status.head()
# Out:
#               createddate  network_connection_status
# 27761 2018-06-22 10:23:29                        0.0
# 27762 2018-06-22 10:23:29                        0.0
# 27763 2018-06-22 10:23:29                        0.0
# 27764 2018-06-22 10:23:29                        0.0
# 27765 2018-06-22 10:23:29                        0.0

# %%
df_network_connection_status.network_connection_status.unique()
# Out:
# array([0., 1., 2., 3., 4., 5.])

# %% [markdown]
# ### building_connection_status

# %%
df_building_connection_status = df[['createddate', 'building_connection_status']]

# %%
df_building_connection_status.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30974 entries, 18449 to 49428
# Data columns (total 2 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   createddate                 30974 non-null  datetime64[ns]
#  1   building_connection_status  21252 non-null  float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 2.0 MB

# %%
df_building_connection_status.isnull().sum()
# Out:
# createddate                      0
# building_connection_status    9722
# dtype: int64

# %%
df_building_connection_status.dropna(subset=['building_connection_status'], inplace=True)
# Out:
# <ipython-input-65-68164e4a8be7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_building_connection_status.dropna(subset=['building_connection_status'], inplace=True)

# %%
df_building_connection_status.head()
# Out:
#               createddate  building_connection_status
# 27761 2018-06-22 10:23:29                         0.0
# 27762 2018-06-22 10:23:29                         0.0
# 27763 2018-06-22 10:23:29                         0.0
# 27764 2018-06-22 10:23:29                         0.0
# 27765 2018-06-22 10:23:29                         0.0

# %%
df_building_connection_status.building_connection_status.unique()
# Out:
# array([0., 6., 1., 5., 2.])

# %% [markdown]
# ### building_competitive_rating

# %%
df_building_competitive_rating = df[['createddate', 'building_competitive_rating']]

# %%
df_building_competitive_rating.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30974 entries, 18449 to 49428
# Data columns (total 2 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   createddate                  30974 non-null  datetime64[ns]
#  1   building_competitive_rating  387 non-null    object
# dtypes: datetime64[ns](1), object(1)
# memory usage: 2.0+ MB

# %%
df_building_competitive_rating.isnull().sum()
# Out:
# createddate                        0
# building_competitive_rating    30587
# dtype: int64

# %%
df_building_competitive_rating.dropna(subset=['building_competitive_rating'], inplace=True)
# Out:
# <ipython-input-71-2bcfcc4528e5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_building_competitive_rating.dropna(subset=['building_competitive_rating'], inplace=True)

# %%
df_building_competitive_rating.head(25)
# Out:
#               createddate building_competitive_rating
# 40863 2018-11-19 12:19:49                       Green
# 40864 2018-11-19 12:19:49                       Green
# 46354 2019-06-13 13:18:36
# 46355 2019-06-13 13:18:36
# 46356 2019-06-13 13:18:36
# 46357 2019-06-13 13:18:36
# 46358 2019-06-13 13:18:36
# 46359 2019-06-13 13:18:36
# 46360 2019-06-13 13:18:36
# 46361 2019-06-13 13:18:36
# 46362 2019-06-13 13:18:36
# 46363 2019-06-13 13:18:36
# 46364 2019-06-13 13:18:36
# 46365 2019-06-13 13:18:36
# 46366 2019-06-13 13:18:36
# 46367 2019-06-13 13:18:36
# 46368 2019-06-13 13:18:36
# 46369 2019-06-13 13:18:36
# 46370 2019-06-13 13:18:36
# 46371 2019-06-13 13:18:36
# 46372 2019-06-13 13:18:36
# 46373 2019-06-13 13:18:36
# 46374 2019-06-13 13:18:36
# 46375 2019-06-13 13:18:36
# 46376 2019-06-13 13:18:36

# %%
df_building_competitive_rating.building_competitive_rating.unique()
# Out:
# array(['Green', ''], dtype=object)

# %% [markdown]
# ### building_category_id

# %%
df_building_category_id = df[['createddate', 'building_category_id']]

# %%
df_building_category_id.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30974 entries, 18449 to 49428
# Data columns (total 2 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   createddate           30974 non-null  datetime64[ns]
#  1   building_category_id  238 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 2.0 MB

# %%
df_building_category_id.isnull().sum()
# Out:
# createddate                 0
# building_category_id    30736
# dtype: int64

# %%
df_building_category_id.dropna(subset=['building_category_id'], inplace=True)
# Out:
# <ipython-input-68-201c43a6d329>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_building_category_id.dropna(subset=['building_category_id'], inplace=True)

# %%
df_building_category_id.head()
# Out:
#               createddate  building_category_id
# 41042 2018-11-30 05:45:19                  24.0
# 41043 2018-11-30 05:45:19                  24.0
# 41044 2018-11-30 09:05:24                  37.0
# 41045 2018-11-30 09:05:24                  37.0
# 41046 2018-11-30 09:05:24                  37.0

# %%
df_building_category_id.building_category_id.unique()
# Out:
# array([24., 37.,  4.,  1., 30.])

# %%
# Creating dataframe a
a = pd.DataFrame()
  
# Creating Dictionary
d = {'id': [1, 2, 10, 12, 13, 14, 15, 16, 17],
     'val1': ['a', 'b', 'c', 'd','d','a', 'b', 'c', 'd']}
  
a = pd.DataFrame(d)
  
# Creating dataframe b
b = pd.DataFrame()
  
# Creating dictionary
d = {'id': ['a', 'b', 'c', 'd'],
     'val1': ['apple', 'box', 'chocolate', 'dog']}
b = pd.DataFrame(d)
  
# right outer join
dff = pd.merge(a, b, left_on='val1',right_on = 'id',  how='left')
  
# display dataframe
dff
# Out:
#    id_x val1_x id_y     val1_y
# 0     1      a    a      apple
# 1     2      b    b        box
# 2    10      c    c  chocolate
# 3    12      d    d        dog
# 4    13      d    d        dog
# 5    14      a    a      apple
# 6    15      b    b        box
# 7    16      c    c  chocolate
# 8    17      d    d        dog
